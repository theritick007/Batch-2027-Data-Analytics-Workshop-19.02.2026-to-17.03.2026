# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/Batch-2027-Data-Analytics-Workshop-19.02.2026-to-17.03.2026/blob/main/Day3Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''arr = [1, 2, 3, 4, 5, 6]
total = 0
for num in arr:
    total += num
print("Sum:", total)
mean = total / len(arr)
print("Mean:", mean)
maximum = arr[0]
minimum = arr[0]
for num in arr:
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num

print("Maximum:", maximum)
print("Minimum:", minimum)
reshaped = [arr[0:3], arr[3:6]]
print("Reshaped:", reshaped)
multiplied = []
for num in arr:
    multiplied.append(num * 2)
print("Element-wise Multiplication:", multiplied)'''
'''numbers = [10, 20, 30, 40, 50, 20]

# Mean
total = 0
for num in numbers:
    total += num
mean = total / len(numbers)
print("Mean:", mean)

# Median
numbers.sort()
n = len(numbers)

if n % 2 == 0:
    median = (numbers[n//2 - 1] + numbers[n//2]) / 2
else:
    median = numbers[n//2]

print("Median:", median)

# Mode
freq = {}
for num in numbers:
    if num in freq:
        freq[num] += 1
    else:
        freq[num] = 1

mode = max(freq, key=freq.get)
print("Mode:", mode)

# Variance
sum_sq = 0
for num in numbers:
    sum_sq += (num - mean) ** 2

variance = sum_sq / n
print("Variance:", variance)

# Standard Deviation
std_dev = variance ** 0.5
print("Standard Deviation:", std_dev)'''
A = [[1, 2], [3, 4]]
B = [[5, 6], [7, 8]]

# Addition
add = [[0, 0], [0, 0]]
for i in range(2):
    for j in range(2):
        add[i][j] = A[i][j] + B[i][j]
print("Addition:", add)

# Subtraction
sub = [[0, 0], [0, 0]]
for i in range(2):
    for j in range(2):
        sub[i][j] = A[i][j] - B[i][j]
print("Subtraction:", sub)

# Multiplication
mul = [[0, 0], [0, 0]]
for i in range(2):
    for j in range(2):
        for k in range(2):
            mul[i][j] += A[i][k] * B[k][j]
print("Multiplication:", mul)

# Transpose of A
transpose = [[0, 0], [0, 0]]
for i in range(2):
    for j in range(2):
        transpose[j][i] = A[i][j]

print("Transpose of A:", transpose)
# Out:
# Addition: [[6, 8], [10, 12]]
# Subtraction: [[-4, -4], [-4, -4]]
# Multiplication: [[19, 22], [43, 50]]
# Transpose of A: [[1, 3], [2, 4]]
