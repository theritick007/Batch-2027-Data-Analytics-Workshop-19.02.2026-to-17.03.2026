# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedantjais04/Batch-2027-Data-Analytics-Workshop-19.02.2026-to-17.03.2026/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'Name':['Tom','Nick','Krish','jack'],
        'Age': [20,21,19,18]}

df = pd.DataFrame(data)


print(df)
# Out:
#     Name  Age
# 0    Tom   20
# 1   Nick   21
# 2  Krish   19
# 3   jack   18

# %%
import statistics

numbers = [10, 20, 30, 40, 50, 20]
mean_value = statistics.mean(numbers)
median_value = statistics.median(numbers)
mode_value = statistics.mode(numbers)
variance_value = statistics.variance(numbers)
std_deviation = statistics.stdev(numbers)

print("Mean:", mean_value)
print("Median:", median_value)
print("Mode:", mode_value)
print("Variance:", variance_value)
print("Standard Deviation:", std_deviation)
# Out:
# Mean: 28.333333333333332
# Median: 25.0
# Mode: 20
# Variance: 216.66666666666666
# Standard Deviation: 14.719601443879744

# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5, 6])
print("Sum:", arr.sum())
print("Mean:", arr.mean())
print("Max:", arr.max())
print("Min:", arr.min())
print("Reshaped:\n", arr.reshape(2, 3))
print("Multiplied:\n", arr * 2)
# Out:
# Sum: 21
# Mean: 3.5
# Max: 6
# Min: 1
# Reshaped:
#  [[1 2 3]
#  [4 5 6]]
# Multiplied:
#  [ 2  4  6  8 10 12]

# %%
import pandas as pd

data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age': [27, 24, 22, 32],
        'Address': ['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

df = pd.DataFrame(data)

print(df[['Name', 'Qualification']])
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
import numpy as np

A = np.array([[1, 2],
              [3, 4]])
B = np.array([[5, 6],
              [7, 8]])
print("Addition:\n", A + B)
print("Subtraction:\n", A - B)
print("Multiplication:\n", A @ B)
print("Transpose of A:\n", A.T)
# Out:
# Addition:
#  [[ 6  8]
#  [10 12]]
# Subtraction:
#  [[-4 -4]
#  [-4 -4]]
# Multiplication:
#  [[19 22]
#  [43 50]]
# Transpose of A:
#  [[1 3]
#  [2 4]]

# %%
import numpy as np

arr = np.random.randint(0, 101, 10)
print("Array:", arr)
print("Mean:", arr.mean())
print("Standard Deviation:", arr.std())
print("Minimum:", arr.min())
print("Maximum:", arr.max())
# Out:
# Array: [33 84 32 75 36 96 12 35 36 33]
# Mean: 47.2
# Standard Deviation: 26.041505332833587
# Minimum: 12
# Maximum: 96

# %%
import numpy as np
from scipy import stats
data = np.array([10, 12, 9, 11, 10, 13, 12, 8])
mean_value = stats.tmean(data)
print("Mean:", mean_value)
t_stat, p_value = stats.ttest_1samp(data, 10)
print("T-Statistic:", t_stat)
print("P-Value:", p_value)
# Out:
# Mean: 10.625
# T-Statistic: 1.0491086363278161
# P-Value: 0.3289933105840345

# %%
from scipy import integrate
import numpy as np
def f(x):
    return x**2
result, error = integrate.quad(f, 0, 3)

print("Definite Integration Result:", result)
print("Estimated Error:", error)
# Out:
# Definite Integration Result: 9.000000000000002
# Estimated Error: 9.992007221626411e-14

# %%
from scipy import optimize
def f(x):
    return x**2 + 4*x + 4
result = optimize.minimize(f, x0=0)
print("Minimum Value:", result.fun)
print("At x =", result.x)
# Out:
# Minimum Value: 0.0
# At x = [-2.00000002]
